# %% [markdown]
# # VENV CREATION/ACTIVATION

# %%
import venv, os, subprocess, sys

VENV_DIR = os.path.join(os.getcwd(), "bank_mkt_venv")
#venv.create(VENV_DIR, with_pip=True)

PYTHON = os.path.join(VENV_DIR, "Scripts", "python.exe")
print(f"Venv Python: {PYTHON}")
print(f"Kernel Python: {sys.executable}")  # Will differ — that's expected
# Out:
# Venv Python: c:\Users\brand\OneDrive\Imágenes\Escritorio\Git Portfolio\bank-marketing-mlop\bank_mkt_venv\Scripts\python.exe
# Kernel Python: c:\Users\brand\OneDrive\Imágenes\Escritorio\Git Portfolio\bank-marketing-mlop\bank_mkt_venv\Scripts\python.exe

# %% [markdown]
# # FOLDER STRUCTURE

# %%
import os
import nbformat

dirs = [
    "app",
    "notebooks"
]
# 
notebooks = [
   "notebooks/01_data_prep.ipynb", #3
    "notebooks/02_model_training.ipynb", #3
    "notebooks/03_model_serving.ipynb", #3
    "notebooks/04_drift_monitoring.ipynb", #3
    "app/main.py", #3
    "requirements.txt",
    ".gitattributes",
    "README.md"
]

for folder in dirs:
    os.makedirs(folder, exist_ok=True)

for nb_path in notebooks:
    nb = nbformat.v4.new_notebook()
    with open(nb_path, "w") as f:
        nbformat.write(nb, f)

# %% [markdown]
# # INSTALL DEPENDENCIES

# %%
import subprocess

result = subprocess.run(
    [PYTHON, "-m", "pip", "install", "-r", "requirements.txt"],
    capture_output=True,
    text=True
)

print(result.stdout)

# %%
# SANITY CHECK: List installed packages in the venv to confirm installation
result = subprocess.run(
    [PYTHON, "-m", "pip", "list"],
    capture_output=True, text=True
)
print(result.stdout)
# Out:
# Package                   Version
# ------------------------- -----------
# appdirs                   1.4.4
# asttokens                 3.0.1
# attrs                     26.1.0
# colorama                  0.4.6
# comm                      0.2.3
# debugpy                   1.8.20
# decorator                 5.3.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# ipykernel                 7.2.0
# ipython                   9.14.0
# ipython_pygments_lexers   1.1.1
# jedi                      0.20.0
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter_client            8.8.0
# jupyter_core              5.9.1
# jupyterlab_widgets        3.0.16
# kiwisolver                1.5.0
# lark                      1.3.1
# litestar-htmx             0.5.0
# Markdown                  3.10.2
# MarkupSafe                3.0.3
# matplotlib-inline         0.2.2
# mdurl                     0.1.2
# mistune                   3.2.1
# msgspec                   0.21.1
# multidict                 6.7.1
# multipart                 1.3.1
# mypy_extensions           1.1.0
# narwhals                  2.22.0
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# numpy                     1.26.4
# opentelemetry-api         1.42.1
# overrides                 7.7.0
# packaging                 24.2
# pandocfilters             1.5.1
# parso                     0.8.7
# pillow                    12.2.0
# pip                       23.2.1
# platformdirs              4.10.0
# prometheus_client         0.25.0
# prompt_toolkit            3.0.52
# protobuf                  5.29.6
# psutil                    7.2.2
# pure_eval                 0.2.3
# pyasn1                    0.6.3
# pycparser                 3.0
# pydantic_core             2.18.4
# Pygments                  2.20.0
# pyparsing                 3.3.2
# python-dateutil           2.9.0.post0
# python-dotenv             1.2.2
# python-json-logger        4.1.0
# python-multipart          0.0.30
# pytz                      2026.2
# pywin32                   311
# pywinpty                  3.0.3
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# referencing               0.37.0
# regex                     2026.5.9
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   2026.5.1
# Send2Trash                2.1.0
# setuptools                65.5.0
# shellingham               1.5.4
# six                       1.17.0
# smmap                     5.0.3
# sniffio                   1.3.1
# soupsieve                 2.8.4
# sqlparse                  0.5.5
# stack-data                0.6.3
# threadpoolctl             3.6.0
# tinycss2                  1.4.0
# tornado                   6.5.6
# tqdm                      4.67.3
# traitlets                 5.15.0
# typing_extensions         4.15.0
# tzdata                    2026.2
# ujson                     5.12.1
# uri-template              1.3.0
# urllib3                   2.7.0
# waitress                  3.0.2
# watchdog                  6.0.0
# wcwidth                   0.7.0
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# websockets                16.0
# widgetsnbextension        4.0.15
# zipp                      4.1.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 6
#       2 result = subprocess.run(
#       3     [PYTHON, "-m", "pip", "list"],
#       4     capture_output=True, text=True
#       5 )
# ----> 6 print(result.stdout).head(100)
#
# AttributeError: 'NoneType' object has no attribute 'head'
